# %%
pip install scikit-surprise
pip install jsonlines
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ---------------------------------------- 0.0/772.0 kB ? eta -:--:--
#      - -------------------------------------- 30.7/772.0 kB ? eta -:--:--
#      ----- -------------------------------- 112.6/772.0 kB 1.7 MB/s eta 0:00:01
#      ------------ ------------------------- 245.8/772.0 kB 1.9 MB/s eta 0:00:01
#      ----------------- -------------------- 348.2/772.0 kB 2.0 MB/s eta 0:00:01
#      ----------------- -------------------- 348.2/772.0 kB 2.0 MB/s eta 0:00:01
#      ------------------- ------------------ 399.4/772.0 kB 1.5 MB/s eta 0:00:01
#      ---------------------- --------------- 450.6/772.0 kB 1.5 MB/s eta 0:00:01
#      ---------------------- --------------- 450.6/772.0 kB 1.5 MB/s eta 0:00:01
#      ---------------------- --------------- 450.6/772.0 kB 1.5 MB/s eta 0:00:01
#      ----------------------------------- -- 716.8/772.0 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 772.0/772.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: joblib>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-surprise) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\anaconda3\lib\site-packages (from scikit-surprise) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\admin\anaconda3\lib\site-packages (from scikit-surprise) (1.10.1)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py): started
#   Building wheel for scikit-surprise (setup.py): finished with status 'done'
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp311-cp311-win_amd64.whl size=1081311 sha256=a645390c67c016cc8a4a1a8eee95a613822c1cf628285948a0757760aae4afad
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\f4\2b\26\e2a5eae55d3b7688995e66abe7f40473aac6c95ddd8ee174a8
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Load the data
df1 = pd.read_csv('df_ca.csv')
df1 = df1.drop('Unnamed: 0', axis=1)
df1
# Out:
#        rating      reviewerName  \
# 0         4.0  william spindler
# 1         5.0  william spindler
# 2         5.0  william spindler
# 3         5.0        Anne Mason
# 4         5.0        Anne Mason
# ...       ...               ...
# 76249     1.0    Richard Wright
# 76250     5.0    Richard Wright
# 76251     5.0        Anna Avila
# 76252     3.0    Lizbethh Tovar
# 76253     1.0    Lizbethh Tovar
#
#                                               reviewText  \
# 0                      Best War Wanton soup in Red Bluff
# 1      This is a review that is long overdo. I've bee...
# 2      Long time favorite Mexican food, always consis...
# 3      Great coffee and location! Check out the used ...
# 4      I've been here dozens of times, and I'll keep ...
# ...                                                  ...
# 76249  This food is disgusting... I am sat in the can...
# 76250  I've eaten Indian food all over the world. A g...
# 76251  I love this store I can spend hours there and ...
# 76252  This place ive been since I was 5 I love this ...
# 76253  If you like greasy, burned and expensive food ...
#
#                                               categories  \
# 0             ['Asian Restaurant', 'Chinese Restaurant']
# 1      ['European Restaurant', 'Italian Restaurant', ...
# 2                                 ['Mexican Restaurant']
# 3                        ['Espresso Bar', 'Coffee Shop']
# 4      ['Sushi Restaurant', 'Asian Restaurant', 'Japa...
# ...                                                  ...
# 76249  ['Mexican Restaurant', 'Latin American Restaur...
# 76250                              ['Indian Restaurant']
# 76251  ['Home Improvement Store', 'Hardware Store', '...
# 76252                     ['Donut Shop', 'Dessert Shop']
# 76253                            ['Barbecue Restaurant']
#
#                 gPlusPlaceId  unixReviewTime    reviewTime  \
# 0      106591714648856494903      1394669496  Mar 12, 2014
# 1      109420033090810328045      1394826388  Mar 14, 2014
# 2      115827996910815192564      1394669713  Mar 12, 2014
# 3      108196901293702895067      1379187049  Sep 14, 2013
# 4      111971088396054239194      1394848761  Mar 14, 2014
# ...                      ...             ...           ...
# 76249  107540363462823386611      1334257465  Apr 12, 2012
# 76250  112541221653908428450      1360468376   Feb 9, 2013
# 76251  100569007418359455686      1347304118  Sep 10, 2012
# 76252  110664528288564115219      1320593088   Nov 6, 2011
# 76253  111461803965468967218      1333245572  Mar 31, 2012
#
#                  gPlusUserId                       gps price  \
# 0      100000032416892623125  [40.179159, -122.236162]   $$$
# 1      100000032416892623125  [40.178074, -122.235234]    $$
# 2      100000032416892623125  [40.175064, -122.242574]    $$
# 3      100000106576186066497  [38.030536, -121.884024]   $$$
# 4      100000106576186066497  [37.961078, -121.748886]    $$
# ...                      ...                       ...   ...
# 76249  106390902683872086099  [33.344747, -118.326901]   $$$
# 76250  106390902683872086099   [38.74622, -121.260129]    $$
# 76251  106390985705853501877  [36.717324, -121.664507]   $$$
# 76252  106391014960118925409   [33.97497, -118.274235]   $$$
# 76253  106391014960118925409  [33.959481, -118.379152]   $$$
#
#                      dtime  hour  minute  second
# 0      2014-03-13 00:11:36     0      11      36
# 1      2014-03-14 19:46:28    19      46      28
# 2      2014-03-13 00:15:13     0      15      13
# 3      2013-09-14 19:30:49    19      30      49
# 4      2014-03-15 01:59:21     1      59      21
# ...                    ...   ...     ...     ...
# 76249  2012-04-12 19:04:25    19       4      25
# 76250  2013-02-10 03:52:56     3      52      56
# 76251  2012-09-10 19:08:38    19       8      38
# 76252  2011-11-06 15:24:48    15      24      48
# 76253  2012-04-01 01:59:32     1      59      32
#
# [76254 rows x 14 columns]

# %%
df2 = pd.read_csv('df_ca_02.csv')
df2
# Out:
#       rating      reviewerName  \
# 0        4.0  william spindler
# 1        5.0  william spindler
# 2        5.0  william spindler
# 3        5.0        Anne Mason
# 4        5.0        Anne Mason
# ...      ...               ...
# 76407    1.0    Richard Wright
# 76408    5.0    Richard Wright
# 76409    5.0        Anna Avila
# 76410    3.0    Lizbethh Tovar
# 76411    1.0    Lizbethh Tovar
#
#                                               reviewText  \
# 0                      Best War Wanton soup in Red Bluff
# 1      This is a review that is long overdo. I've bee...
# 2      Long time favorite Mexican food, always consis...
# 3      Great coffee and location! Check out the used ...
# 4      I've been here dozens of times, and I'll keep ...
# ...                                                  ...
# 76407  This food is disgusting... I am sat in the can...
# 76408  I've eaten Indian food all over the world. A g...
# 76409  I love this store I can spend hours there and ...
# 76410  This place ive been since I was 5 I love this ...
# 76411  If you like greasy, burned and expensive food ...
#
#                                               categories  \
# 0             ['Asian Restaurant', 'Chinese Restaurant']
# 1      ['European Restaurant', 'Italian Restaurant', ...
# 2                                 ['Mexican Restaurant']
# 3                        ['Espresso Bar', 'Coffee Shop']
# 4      ['Sushi Restaurant', 'Asian Restaurant', 'Japa...
# ...                                                  ...
# 76407  ['Mexican Restaurant', 'Latin American Restaur...
# 76408                              ['Indian Restaurant']
# 76409  ['Home Improvement Store', 'Hardware Store', '...
# 76410                     ['Donut Shop', 'Dessert Shop']
# 76411                            ['Barbecue Restaurant']
#
#                 gPlusPlaceId unixReviewTime    reviewTime  \
# 0      106591714648856494903     1394669496  Mar 12, 2014
# 1      109420033090810328045     1394826388  Mar 14, 2014
# 2      115827996910815192564     1394669713  Mar 12, 2014
# 3      108196901293702895067     1379187049  Sep 14, 2013
# 4      111971088396054239194     1394848761  Mar 14, 2014
# ...                      ...            ...           ...
# 76407  107540363462823386611     1334257465  Apr 12, 2012
# 76408  112541221653908428450     1360468376   Feb 9, 2013
# 76409  100569007418359455686     1347304118  Sep 10, 2012
# 76410  110664528288564115219     1320593088   Nov 6, 2011
# 76411  111461803965468967218     1333245572  Mar 31, 2012
#
#                  gPlusUserId                       gps price  reviewLength  \
# 0      100000032416892623125  [40.179159, -122.236162]   $$$          33.0
# 1      100000032416892623125  [40.178074, -122.235234]    $$         838.0
# 2      100000032416892623125  [40.175064, -122.242574]    $$          69.0
# 3      100000106576186066497  [38.030536, -121.884024]   $$$          74.0
# 4      100000106576186066497  [37.961078, -121.748886]    $$         105.0
# ...                      ...                       ...   ...           ...
# 76407  106390902683872086099  [33.344747, -118.326901]   $$$         362.0
# 76408  106390902683872086099   [38.74622, -121.260129]    $$         701.0
# 76409  106390985705853501877  [36.717324, -121.664507]   $$$          73.0
# 76410  106391014960118925409   [33.97497, -118.274235]   $$$          89.0
# 76411  106391014960118925409  [33.959481, -118.379152]   $$$          90.0
#
#        reviewHour  priceRank
# 0             0.0        3.0
# 1            19.0        3.0
# 2             0.0        3.0
# 3            19.0        3.0
# 4             1.0        3.0
# ...           ...        ...
# 76407        19.0        3.0
# 76408         3.0        3.0
# 76409        19.0        3.0
# 76410        15.0        3.0
# 76411         1.0        3.0
#
# [76412 rows x 13 columns]

# %%
import json
import gzip
import time

# %% [markdown]
# ### Begin

# %%
def find_PlaceId(name):
    file_path = 'data/places.clean.json.gz'
    gplusPlaceId=""
    for review in read_reviews(file_path):
        gplusPlaceName=""
        message_value = json.dumps(review)
        if review["name"] == name:
            gplusPlaceId = review["gPlusPlaceId"]
            break
    return gplusPlaceId

# %%
def find_name(place_id):
    file_path = 'data/places.clean.json.gz'
    gplusPlaceName=""
    for review in read_reviews(file_path):
        gplusPlaceName=""
        message_value = json.dumps(review)
        if review["gPlusPlaceId"] == place_id:
            gplusPlaceName = review["name"]
            break
    return gplusPlaceName

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def find_similar_categories(input_category, categories, ratings, reviewer_names, gps):
    # Combine the input category, categories, ratings, and reviewer names into a list
    all_categories = [(input_category, 1.0, "", "")] + list(zip(categories, ratings, reviewer_names, gps))
    
    # Create a TfidfVectorizer
    vectorizer = TfidfVectorizer()
    
    # Transform the categories into TF-IDF vectors
    tfidf_matrix = vectorizer.fit_transform([category for category, _, _, _ in all_categories])
    
    # Calculate the cosine similarity between the input category and all other categories
    similarity_scores = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1:])
    
    # Get the indices of the most similar categories
    most_similar_indices = similarity_scores.argsort()[0][::-1]
    
    # Sort the ratings based on the category indices
    sorted_ratings = sorted(zip(most_similar_indices, ratings, reviewer_names, gps), key=lambda x: x[1], reverse=True)
    
    unique_categories = set()
    unique_sorted_ratings = []
    
    # Filter out duplicate categories
    for index, rating, reviewer_name, gps_value in sorted_ratings:
        category = categories[index]
        if category not in unique_categories:
            unique_categories.add(category)
            unique_sorted_ratings.append((index, rating, reviewer_name, gps_value))
    
    return most_similar_indices[:5], unique_sorted_ratings

# %% [markdown]
# ### Name input ( Chưa chạy được)

# %%
103732895939896117386
# Read the data from a CSV file
data = pd.read_csv('df_ca.csv')

# Get the categories, ratings, reviewer names, and GPS columns
categories = data['categories'].tolist()
ratings = data['rating'].tolist()
reviewer_names = data['reviewerName'].tolist()
gps = data['gps'].tolist()
gPlusPlaceId = data['gPlusPlaceId']

# Input name
input_name = input("Name: ")

input_gplus_place_id = find_PlaceId(input_name)

# Tìm danh mục (category) tương ứng với input_gplus_place_id
filtered_data = data[data['gPlusPlaceId'] == input_gplus_place_id]
input_category = filtered_data['categories'].iloc[0]

if input_category:
    # Find similar categories and their indices, along with sorted ratings
    similar_category_indices, sorted_ratings = find_similar_categories(input_category, categories, ratings, reviewer_names, gps)

    # Print the similar categories, indices, ratings, reviewer names, and GPS values in the desired format
    print("Indices, Similar Categories, Ratings, Reviewer Names, and GPS:")
    for index, rating, reviewer_name, gps_value in sorted_ratings[:5]:
        place_name = ""
        category = categories[index]
        gplus_place_id = gPlusPlaceId[index]
        place_name = find_name(gplus_place_id)
        print(f"{index:5}  {category:60} {rating:<5} {reviewer_name} {gps_value} {gplus_place_id} {place_name}")
else:
    print("Không tìm thấy gPlusPlaceId trong dữ liệu.")
# Out:
# Name: Peking Chinese Restaurant
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[103], line 18
#      16 # Tìm danh mục (category) tương ứng với input_gplus_place_id
#      17 filtered_data = data[data['gPlusPlaceId'] == input_gplus_place_id]
# ---> 18 input_category = filtered_data['categories'].iloc[0]
#      20 if input_category:
#      21     # Find similar categories and their indices, along with sorted ratings
#      22     similar_category_indices, sorted_ratings = find_similar_categories(input_category, categories, ratings, reviewer_names, gps)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ### Place ID input

# %%
# Read the data from a CSV file
data = pd.read_csv('df_ca.csv')

# Get the categories, ratings, reviewer names, and GPS columns
categories = data['categories'].tolist()
ratings = data['rating'].tolist()
reviewer_names = data['reviewerName'].tolist()
gps = data['gps'].tolist()
gPlusPlaceId = data['gPlusPlaceId']

# Input gPlusPlaceId
input_gplus_place_id = input("Nhập gPlusPlaceId: ")

# Tìm danh mục (category) tương ứng với input_gplus_place_id
filtered_data = data[data['gPlusPlaceId'] == input_gplus_place_id]
input_category = filtered_data['categories'].iloc[0]

if input_category:
    # Find similar categories and their indices, along with sorted ratings
    similar_category_indices, sorted_ratings = find_similar_categories(input_category, categories, ratings, reviewer_names, gps)

    # Print the similar categories, indices, ratings, reviewer names, and GPS values in the desired format
    print("Indices, Similar Categories, Ratings, Reviewer Names, GPS, Place_ID and Name:")
    for index, rating, reviewer_name, gps_value in sorted_ratings[:5]:
        category = categories[index]
        gplus_place_id = gPlusPlaceId[index]
        place_name = find_name(gplus_place_id)
        print(f"{index:5}  {category:60} {rating:<5} {reviewer_name} {gps_value} {gplus_place_id} {place_name}")
else:
    print("Không tìm thấy gPlusPlaceId trong dữ liệu.")
# Out:
# Nhập gPlusPlaceId: 115827996910815192564
# Indices, Similar Categories, Ratings, Reviewer Names, and GPS:
#   953  ['Mexican Restaurant']                                       5.0   william spindler [40.178074, -122.235234] 116028272836626536987 Taquerias El Farolito
# 68702  ['Restaurant Mexican']                                       5.0   Walter Touceda [33.862883, -118.092693] 113459885284990886655 Ernie Jr's Taco House
# 49778  ['Restaurant', 'Mexican Restaurant']                         5.0   Mike Cohen [37.795233, -122.39343] 109140634583578213228 El Borrego Restaurant
# 29333  ['Mexican Restaurant', 'Bar']                                5.0   Rajiv Bhan [37.787475, -122.41452] 102564249825299113691 Velvet Cantina
#  2518  ['Mexican Restaurant', 'Seafood Restaurant']                 5.0   Justin “Ratchet” Hickman [35.126281, -120.596555] 100724315518047021135 Rockin' Baja Lobster - Coastal Cantina Newport Beach
